# %% [markdown]
# ## FreiHAND dataset class

# %%
from torch.utils.data import Dataset, DataLoader
from os.path import join
from os import listdir
from PIL import Image
import torchvision.transforms.functional as TF

class FreiHANDDataset(Dataset):
    def __init__(self, root):
        self.root = root
        self.paths = listdir(join(root, 'training', 'mask'))
        size = len(self.paths)

    def __getitem__(self, item):
        id = self.paths[item]
        img_path = join(self.root, 'training', 'rgb', id)
        mask_path = join(self.root, 'training', 'mask', id)

        img = Image.open(img_path).convert('RGB')
        mask = Image.open(mask_path).convert('L')
        sample = {
            'img': TF.to_tensor(img), 
            'mask': TF.to_tensor(mask)
        }

        return sample

    def __len__(self):
        return len(self.paths)

# %%
from torchvision.transforms import transforms

def view_image(dataset_path):
    dataset = FreiHANDDataset(
        root=dataset_path
    )
    dataloader = DataLoader(
        dataset,
        batch_size=1
    )
    for batch in dataloader:
        imgs = batch['img']
        masks = batch['mask']
        for img, mask in zip(imgs, masks):
            transforms.ToPILImage()(img).show()
            transforms.ToPILImage()(mask).show()
        break

# %%
FREIHAND_PATH = '/home/popa/Documents/fingertip_detection_and_tracking/datasets/fdt/segmentation_datasets/FreiHAND_pub_v2'
view_image(
    dataset_path = FREIHAND_PATH
)
# Out:
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# ...
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# Failed to register: Timeout was reached
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 FREIHAND_PATH = '/home/popa/Documents/fingertip_detection_and_tracking/datasets/fdt/segmentation_datasets/FreiHAND_pub_v2'
# ----> 2 view_image(
#       3     dataset_path = FREIHAND_PATH
#       4 )
#
# Cell In[25], line 15, in view_image(dataset_path)
#      13 masks = batch['mask']
#      14 for img, mask in zip(imgs, masks):
# ---> 15     transforms.ToPILImage()(img).show()
#      16     transforms.ToPILImage()(mask).show()
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/Image.py:2485, in Image.show(self, title)
#    2465 def show(self, title=None):
#    2466     """
#    2467     Displays this image. This method is mainly intended for debugging purposes.
#    2468
#    (...)
#    2482     :param title: Optional title to use for the image window, where possible.
#    2483     """
# -> 2485     _show(self, title=title)
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/Image.py:3508, in _show(image, **options)
#    3505 def _show(image, **options):
#    3506     from . import ImageShow
# -> 3508     ImageShow.show(image, **options)
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/ImageShow.py:62, in show(image, title, **options)
#      53 r"""
#      54 Display a given image.
#      55
#    (...)
#      59 :returns: ``True`` if a suitable viewer was found, ``False`` otherwise.
#      60 """
#      61 for viewer in _viewers:
# ---> 62     if viewer.show(image, title=title, **options):
#      63         return True
#      64 return False
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/ImageShow.py:86, in Viewer.show(self, image, **options)
#      83     if image.mode != base:
#      84         image = image.convert(base)
# ---> 86 return self.show_image(image, **options)
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/ImageShow.py:112, in Viewer.show_image(self, image, **options)
#     110 def show_image(self, image, **options):
#     111     """Display the given image."""
# --> 112     return self.show_file(self.save_image(image), **options)
#
# File ~/miniconda3/envs/fdt/lib/python3.10/site-packages/PIL/ImageShow.py:233, in XDGViewer.show_file(self, path, **options)
#     231         msg = "Missing required argument: 'path'"
#     232         raise TypeError(msg)
# --> 233 subprocess.Popen(["xdg-open", path])
#     234 return 1
#
# File ~/miniconda3/envs/fdt/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     967         if self.text_mode:
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#     982     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/fdt/lib/python3.10/subprocess.py:1793, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1790     self._child_created = True
#    1791 finally:
#    1792     # be sure the FD is closed no matter what
# -> 1793     os.close(errpipe_write)
#    1795 self._close_pipe_fds(p2cread, p2cwrite,
#    1796                      c2pread, c2pwrite,
#    1797                      errread, errwrite)
#    1799 # Wait for exec to fail or succeed; possibly raising an
#    1800 # exception (limited in size)
#
# KeyboardInterrupt:
